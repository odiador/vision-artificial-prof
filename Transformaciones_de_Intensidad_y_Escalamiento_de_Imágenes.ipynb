# %% [markdown]
# <a href="https://colab.research.google.com/github/odiador/vision-artificial-prof/blob/main/Transformaciones_de_Intensidad_y_Escalamiento_de_Im%C3%A1genes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ACTIVIDAD 4 Transformaciones de Intensidad y Escalamiento de Imágenes
# ## Objetivo General
# Aplicar procesos básicos de procesamiento digital de imágenes mediante:
# - Umbralización
# - Operaciones aritméticas con una constante
# - Amplificación (aumento de tamaño)
# - Reducción (disminución de tamaño)
#
# Analizando su impacto visual y cuantitativo.
#
# # Objetivos Específicos
#
# - Comprender cómo cambian los valores de intensidad al modificar la imagen con constantes.
# - Analizar el efecto del brillo y contraste.
# - Implementar procesos de escalamiento sin usar funciones automáticas avanzadas.
# - Evaluar pérdida de información al reducir imágenes.
# - Comparar resultados visuales y numéricos.

# %% [markdown]
# # PARTE 1 - Preparación
# Trabajar con mínimo tres imágenes:
# - Imagen con alto contraste
# - Imagen con bajo contraste
# - Imagen natural
#
# Convertir todas a escala de grises utilizando su método propio.
